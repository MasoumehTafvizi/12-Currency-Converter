# %%
import requests

# %%
url = "https://jsonplaceholder.typicode.com/todos?completed=true"

# %%
response = requests.get(url)

# %%
print(response.status_code)
# Out:
# 200

# %%
response.json()
# Out:
# [{'userId': 1, 'id': 4, 'title': 'et porro tempora', 'completed': True},
#  {'userId': 1,
#   'id': 8,
#   'title': 'quo adipisci enim quam ut ab',
#   'completed': True},
#  {'userId': 1,
#   'id': 10,
#   'title': 'illo est ratione doloremque quia maiores aut',
#   'completed': True},
#  {'userId': 1,
#   'id': 11,
#   'title': 'vero rerum temporibus dolor',
#   'completed': True},
#  {'userId': 1,
#   'id': 12,
#   'title': 'ipsa repellendus fugit nisi',
#   'completed': True},
#  {'userId': 1,
#   'id': 14,
#   'title': 'repellendus sunt dolores architecto voluptatum',
#   'completed': True},
#  {'userId': 1,
#   'id': 15,
#   'title': 'ab voluptatum amet voluptas',
#   'completed': True},
#  {'userId': 1,
#   'id': 16,
#   'title': 'accusamus eos facilis sint et aut voluptatem',
#   'completed': True},
#  {'userId': 1,
#   'id': 17,
#   'title': 'quo laboriosam deleniti aut qui',
#   'completed': True},
#  {'userId': 1,
#   'id': 19,
# ...

# %%
params = {
    "completed": "true"
}

# %%
response = requests.get(url, params=params)
response.json()
# Out:
# [{'userId': 1, 'id': 4, 'title': 'et porro tempora', 'completed': True},
#  {'userId': 1,
#   'id': 8,
#   'title': 'quo adipisci enim quam ut ab',
#   'completed': True},
#  {'userId': 1,
#   'id': 10,
#   'title': 'illo est ratione doloremque quia maiores aut',
#   'completed': True},
#  {'userId': 1,
#   'id': 11,
#   'title': 'vero rerum temporibus dolor',
#   'completed': True},
#  {'userId': 1,
#   'id': 12,
#   'title': 'ipsa repellendus fugit nisi',
#   'completed': True},
#  {'userId': 1,
#   'id': 14,
#   'title': 'repellendus sunt dolores architecto voluptatum',
#   'completed': True},
#  {'userId': 1,
#   'id': 15,
#   'title': 'ab voluptatum amet voluptas',
#   'completed': True},
#  {'userId': 1,
#   'id': 16,
#   'title': 'accusamus eos facilis sint et aut voluptatem',
#   'completed': True},
#  {'userId': 1,
#   'id': 17,
#   'title': 'quo laboriosam deleniti aut qui',
#   'completed': True},
#  {'userId': 1,
#   'id': 19,
# ...

# %%
# %env EMAIL_PASSWORD='jn_pass'
# %env EMAIL_USERNAME='jn_user'
# Out:
# env: EMAIL_PASSWORD='jn_pass'
# env: EMAIL_USERNAME='jn_user'

# %%
# %env unset EMAIL_PASSWORD
# Out:
# env: unset=EMAIL_PASSWORD

# %%
# %env EMAIL_PASSWORD
# Out:
# "'jn_pass'"

# %%
# %env EMAIL_PASSWORD
# Out:
# "'jn_pass'"

# %%
# %env EMAIL_USERNAME
# Out:
# "'jn_user'"

# %%
import os

os.environ

# %%
os.environ.get("unset")

# %%
EMAIL_PASSWORD = os.environ.get('EMAIL_PASSWORD')
EMAIL_USERNAME = os.environ.get('EMAIL_USERNAME')

# %%
# %env EXCHANGE_CURRENCY_API_KEY='MY_API_KEY'
# Out:
# env: EXCHANGE_CURRENCY_API_KEY='MY_API_KEY'

# %%
os.environ.get('EXCHANGE_CURRENCY_API_KEY')
# Out:
# "'MY_API_KEY'"

# %%
import requests

# %%
# The base URL for the Google Books API
url = "https://www.googleapis.com/books/v1/volumes"

# %%
params = {
    'q': 'Python Programming'
}

# %%
len(requests.get(url, params=params).json()['items'])
# Out:
# 10

# %%
import os
import requests

# %%
url = "https://api.giphy.com/v1/gifs/trending"

# %%
# %env GIPHY_API_KEY=s8w5pYmEdbBYLZt5WxVaxN2wM0GZh9UK
# Out:
# env: GIPHY_API_KEY=s8w5pYmEdbBYLZt5WxVaxN2wM0GZh9UK

# %%
params = {
    'api_key' : os.environ.get('GIPHY_API_KEY'),
    'limit' : 10
}

# %%
response = requests.get(url, params=params)

# %%
if response.status_code == 200:
    data = response.json()
    for gif in data['data']:
        print(gif['title'])
        print(gif['images']['original']['url'])
        print('---')
# Out:
# Loop Portrait GIF by Originals
# https://media1.giphy.com/media/v1.Y2lkPTRlY2U1OTUxeGR3ZWE1bjBrYm5tcmF3dTVpZnJpeGV4dGV3d2lxOWQxMG5hcXJqciZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/2jMCWE4zGelRa4NrDv/giphy.gif
# ---
# 6 7 Hamster GIF by Grind
# https://media0.giphy.com/media/v1.Y2lkPTRlY2U1OTUxeGR3ZWE1bjBrYm5tcmF3dTVpZnJpeGV4dGV3d2lxOWQxMG5hcXJqciZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/YaP3iYxN3T8nIEN5rD/giphy.gif
# ---
# Happy Aj Styles GIF by WWE
# https://media4.giphy.com/media/v1.Y2lkPTRlY2U1OTUxeGR3ZWE1bjBrYm5tcmF3dTVpZnJpeGV4dGV3d2lxOWQxMG5hcXJqciZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/7faVamiIy0b1Tj3XPZ/giphy.gif
# ---
# Dog Hello GIF
# https://media0.giphy.com/media/v1.Y2lkPTRlY2U1OTUxeGR3ZWE1bjBrYm5tcmF3dTVpZnJpeGV4dGV3d2lxOWQxMG5hcXJqciZlcD12MV9naWZzX3RyZW5kaW5nJmN0PWc/WK7omsLop0431tZjXb/giphy.gif
# ---
# I Love You Heart GIF by Pudgy Penguins
# ...
