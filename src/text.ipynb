# %%
import requests

# %%
def get_exchange_rate(base_currency, target_currency):
    url = f"https://api.exchangerate-api.com/v4/latest/{base_currency}"
    response = requests.get(url)
    return response.json().get('rates').get(target_currency), response.json().get('time_last_updated')

# %%
def convert_currency(amount, exchange_rate):
    return amount * exchange_rate

# %%
base_currency = 'USD'
target_currency = 'CAD'

# %%
exchange_rate = get_exchange_rate(base_currency, target_currency)

# %%
base_amount = 100
targetted_amount = convert_currency(base_amount, exchange_rate)

# %%
targetted_amount
# Out:
# (1.37,
#  1772064002,
#  1.37,
#  1772064002,
#  1.37,
#  1772064002,
#  1.37,
#  1772064002,
#  1.37,
#  1772064002,
#  1.37,
#  1772064002,
#  1.37,
#  1772064002,
#  1.37,
#  1772064002,
#  1.37,
#  1772064002,
#  1.37,
#  1772064002,
#  1.37,
#  1772064002,
#  1.37,
#  1772064002,
#  1.37,
#  1772064002,
#  1.37,
#  1772064002,
#  1.37,
#  1772064002,
#  1.37,
#  1772064002,
#  1.37,
#  1772064002,
#  1.37,
#  1772064002,
#  1.37,
#  1772064002,
#  1.37,
#  1772064002,
#  1.37,
#  1772064002,
#  1.37,
#  1772064002,
#  1.37,
#  1772064002,
#  1.37,
#  1772064002,
#  1.37,
#  1772064002,
#  1.37,
#  1772064002,
#  1.37,
#  1772064002,
#  1.37,
#  1772064002,
#  1.37,
#  1772064002,
#  1.37,
#  1772064002,
#  1.37,
#  1772064002,
#  1.37,
#  1772064002,
#  1.37,
#  1772064002,
#  1.37,
#  1772064002,
#  1.37,
#  1772064002,
#  1.37,
#  1772064002,
#  1.37,
#  1772064002,
#  1.37,
#  1772064002,
#  1.37,
#  1772064002,
#  1.37,
#  1772064002,
#  1.37,
#  1772064002,
#  1.37,
#  1772064002,
#  1.37,
#  1772064002,
#  1.37,
#  1772064002,
#  1.37,
#  1772064002,
#  1.37,
#  1772064002,
#  1.37,
#  1772064002,
#  1.37,
#  1772064002,
#  1.37,
#  1772064002,
#  1.37,
#  1772064002,
#  1.37,
#  1772064002,
#  1.37,
#  1772064002,
#  1.37,
#  1772064002,
#  1.37,
#  1772064002,
#  1.37,
#  1772064002,
#  1.37,
#  1772064002,
#  1.37,
#  1772064002,
#  1.37,
#  1772064002,
#  1.37,
#  1772064002,
#  1.37,
#  1772064002,
#  1.37,
#  1772064002,
#  1.37,
#  1772064002,
#  1.37,
#  1772064002,
#  1.37,
#  1772064002,
#  1.37,
#  1772064002,
#  1.37,
#  1772064002,
#  1.37,
#  1772064002,
#  1.37,
#  1772064002,
#  1.37,
#  1772064002,
#  1.37,
#  1772064002,
#  1.37,
#  1772064002,
#  1.37,
#  1772064002,
#  1.37,
#  1772064002,
#  1.37,
#  1772064002,
#  1.37,
#  1772064002,
#  1.37,
#  1772064002,
#  1.37,
#  1772064002,
#  1.37,
#  1772064002,
#  1.37,
#  1772064002,
#  1.37,
#  1772064002,
#  1.37,
#  1772064002,
#  1.37,
#  1772064002,
#  1.37,
#  1772064002,
#  1.37,
#  1772064002,
#  1.37,
#  1772064002,
#  1.37,
#  1772064002,
#  1.37,
#  1772064002,
#  1.37,
#  1772064002,
#  1.37,
#  1772064002,
#  1.37,
#  1772064002,
#  1.37,
#  1772064002,
#  1.37,
#  1772064002,
#  1.37,
#  1772064002,
#  1.37,
#  1772064002,
#  1.37,
#  1772064002,
#  1.37,
#  1772064002,
#  1.37,
#  1772064002,
#  1.37,
#  1772064002,
#  1.37,
#  1772064002,
#  1.37,
#  1772064002)

# %%
# %pip install currencies
# Out:
# Requirement already satisfied: currencies in /Users/imasyma/miniconda3/envs/main_python/lib/python3.13/site-packages (2020.12.12)
# Note: you may need to restart the kernel to use updated packages.

# %%
import currencies

# %%
list(currencies.MONEY_FORMATS.keys())
# Out:
# ['AED',
#  'AFN',
#  'ALL',
#  'AMD',
#  'ANG',
#  'AOA',
#  'ARS',
#  'AUD',
#  'AWG',
#  'AZN',
#  'BAM',
#  'BBD',
#  'BDT',
#  'BGN',
#  'BHD',
#  'BND',
#  'BOB',
#  'BRL',
#  'BSD',
#  'BTN',
#  'BWP',
#  'BYR',
#  'BZD',
#  'CAD',
#  'CHF',
#  'CLP',
#  'CNY',
#  'COP',
#  'CRC',
#  'CZK',
#  'DKK',
#  'DOP',
#  'DZD',
#  'EGP',
#  'ETB',
#  'EUR',
#  'FJD',
#  'GBP',
#  'GEL',
#  'GHS',
#  'GMD',
#  'GTQ',
#  'GYD',
#  'HKD',
#  'HNL',
#  'HRK',
#  'HUF',
#  'IDR',
#  'ILS',
#  'INR',
#  'ISK',
#  'JEP',
#  'JMD',
#  'JOD',
#  'JPY',
#  'KES',
#  'KGS',
#  'KHR',
#  'KRW',
#  'KWD',
#  'KYD',
#  'KZT',
#  'LBP',
#  'LKR',
#  'LTL',
#  'LVL',
#  'MAD',
#  'MDL',
#  'MGA',
#  'MKD',
#  'MMK',
#  'MNT',
#  'MOP',
#  'MUR',
#  'MVR',
#  'MXN',
#  'MYR',
#  'MZN',
#  'NAD',
#  'NGN',
#  'NIO',
#  'NOK',
#  'NPR',
#  'NZD',
#  'OMR',
#  'PEN',
#  'PGK',
#  'PHP',
#  'PKR',
#  'PLN',
#  'PYG',
#  'QAR',
#  'RON',
#  'RSD',
#  'RUB',
#  'RWF',
#  'SAR',
#  'SCR',
#  'SEK',
#  'SGD',
#  'STD',
#  'SYP',
#  'THB',
#  'TND',
#  'TRY',
#  'TTD',
#  'TWD',
#  'TZS',
#  'UAH',
#  'UGX',
#  'USD',
#  'UYU',
#  'VEF',
#  'VND',
#  'VUV',
#  'WST',
#  'XAF',
#  'XBT',
#  'XCD',
#  'XOF',
#  'XPF',
#  'ZAR',
#  'ZMW']

# %%
url = f"https://api.exchangerate-api.com/v4/latest/{base_currency}"
response = requests.get(url)

# %%
response.json().get('time_last_updated')
# Out:
# 1772064002

# %%
import humanize
from datetime import datetime

exchange_rate, time_last_updated = get_exchange_rate(base_currency, target_currency)
time_diff = datetime.now() - datetime.fromtimestamp(time_last_updated)
# Use humanize to format the time difference
time_ago = humanize.naturaltime(time_diff)
time_ago
# Out:
# '17 hours ago'

# %%
list(response.json().get('rates').keys())
# Out:
# ['USD',
#  'AED',
#  'AFN',
#  'ALL',
#  'AMD',
#  'ANG',
#  'AOA',
#  'ARS',
#  'AUD',
#  'AWG',
#  'AZN',
#  'BAM',
#  'BBD',
#  'BDT',
#  'BGN',
#  'BHD',
#  'BIF',
#  'BMD',
#  'BND',
#  'BOB',
#  'BRL',
#  'BSD',
#  'BTN',
#  'BWP',
#  'BYN',
#  'BZD',
#  'CAD',
#  'CDF',
#  'CHF',
#  'CLF',
#  'CLP',
#  'CNH',
#  'CNY',
#  'COP',
#  'CRC',
#  'CUP',
#  'CVE',
#  'CZK',
#  'DJF',
#  'DKK',
#  'DOP',
#  'DZD',
#  'EGP',
#  'ERN',
#  'ETB',
#  'EUR',
#  'FJD',
#  'FKP',
#  'FOK',
#  'GBP',
#  'GEL',
#  'GGP',
#  'GHS',
#  'GIP',
#  'GMD',
#  'GNF',
#  'GTQ',
#  'GYD',
#  'HKD',
#  'HNL',
#  'HRK',
#  'HTG',
#  'HUF',
#  'IDR',
#  'ILS',
#  'IMP',
#  'INR',
#  'IQD',
#  'IRR',
#  'ISK',
#  'JEP',
#  'JMD',
#  'JOD',
#  'JPY',
#  'KES',
#  'KGS',
#  'KHR',
#  'KID',
#  'KMF',
#  'KRW',
#  'KWD',
#  'KYD',
#  'KZT',
#  'LAK',
#  'LBP',
#  'LKR',
#  'LRD',
#  'LSL',
#  'LYD',
#  'MAD',
#  'MDL',
#  'MGA',
#  'MKD',
#  'MMK',
#  'MNT',
#  'MOP',
#  'MRU',
#  'MUR',
#  'MVR',
#  'MWK',
#  'MXN',
#  'MYR',
#  'MZN',
#  'NAD',
#  'NGN',
#  'NIO',
#  'NOK',
#  'NPR',
#  'NZD',
#  'OMR',
#  'PAB',
#  'PEN',
#  'PGK',
#  'PHP',
#  'PKR',
#  'PLN',
#  'PYG',
#  'QAR',
#  'RON',
#  'RSD',
#  'RUB',
#  'RWF',
#  'SAR',
#  'SBD',
#  'SCR',
#  'SDG',
#  'SEK',
#  'SGD',
#  'SHP',
#  'SLE',
#  'SLL',
#  'SOS',
#  'SRD',
#  'SSP',
#  'STN',
#  'SYP',
#  'SZL',
#  'THB',
#  'TJS',
#  'TMT',
#  'TND',
#  'TOP',
#  'TRY',
#  'TTD',
#  'TVD',
#  'TWD',
#  'TZS',
#  'UAH',
#  'UGX',
#  'UYU',
#  'UZS',
#  'VES',
#  'VND',
#  'VUV',
#  'WST',
#  'XAF',
#  'XCD',
#  'XCG',
#  'XDR',
#  'XOF',
#  'XPF',
#  'YER',
#  'ZAR',
#  'ZMW',
#  'ZWG',
#  'ZWL']

# %%
from functools import cache, lru_cache

# %%
@lru_cache(maxsize=3)
def fibonacci(n):
    if n < 2:
        return n
    return fibonacci(n-1) + fibonacci(n-2)

# %%
fibonacci(1000)
# Out:
# 43466557686937456435688527675040625802564660517371780402481729089536555417949051890403879840079255169295922593080322634775209689623239873322471161642996440906533187938298969649928516003704476137795166849228875

# %%
fibonacci.cache_info()
# Out:
# CacheInfo(hits=998, misses=1001, maxsize=3, currsize=3)

# %%
fibonacci.cache_clear()

# %%
fibonacci.cache_info()
# Out:
# CacheInfo(hits=0, misses=0, maxsize=3, currsize=0)

# %%
# %pip install cachetools
# Out:
# Requirement already satisfied: cachetools in /Users/imasyma/miniconda3/envs/main_python/lib/python3.13/site-packages (6.2.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
from cachetools import cached, TTLCache

# %%
ttl_cache = TTLCache(maxsize=3, ttl=10)

# %%
import time
@cached(cache=ttl_cache)
def get_data(key):
    time.sleep(2)
    return f"Data for {key}"

# %%
get_data("key1")
# Out:
# 'Data for key1'

# %%
# %pip install humanize
# Out:
# Requirement already satisfied: humanize in /Users/imasyma/miniconda3/envs/main_python/lib/python3.13/site-packages (4.15.0)
# Note: you may need to restart the kernel to use updated packages.
